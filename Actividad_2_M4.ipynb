# %% [markdown]
# #Actividad 2 Módulo 4

# %% [markdown]
# Preguntas guía
#
# - Distribución de probabilidad
#
# Una distribución de probabilidad es aquella que permite establecer toda la gama de resultados probables de ocurrir en un experimento
# determinado. Es decir, describe la probabilidad de que un evento se
# realice en el futuro.
#
# - Variables Aleatorias(discretas y Continuas)
#
# Es una función que asocia un número real, perfectamente definido, a cada punto muestral y estas pueden ser:
#
# 1. Discretos: número finito o infinito numerable de elementos.
#
# 2. Continuos: número infinito no numerable de elementos.
#
# - Distribución Normal
#
# Una función que asocia un número real, perfectamente definido, a cada punto muestral.
#
# Dos parámetros determinan una distribución normal: la media y la
# desviación estándar.
#
# La distribución normal es un modelo teórico capaz de aproximar
# satisfactoriamente un valor de una variable aleatoria a un valor real. En otras palabras, la distribución normal adapta una variable aleatoria a una función que depende de la media y la desviación típica. Es decir, la función y la variable aleatoria tendrán la misma representación pero con ligeras diferencias.
#
# Características
# 1. Simétrica respecto a su media. En otras palabras, la media actúa como
# espejo en la distribución y hace que ambas colas sean idénticas y, por
# tanto, simétricas.
# 2. Media = Moda = Mediana. Las medidas de centralización son iguales
# porque la distribución es simétrica.
# 3. La distribución cambia de curvatura o tiene puntos de inflexión en los
# puntos del eje horizontal:
#
# - Distribución Binomial
#
# Una distribución binomial es una distribución de probabilidad discreta que describe el número de éxitos al realizar n experimentos
# independientes entre sí, acerca de una variable aleatoria.
#
# Existen una gran diversidad de experimentos o sucesos que pueden ser
# caracterizados bajo esta distribución de probabilidad. Imaginemos el
# lanzamiento de una moneda en el que definimos el suceso “sacar cara”
# como el éxito. Si lanzamos 5 veces la moneda y contamos los éxitos (sacar cara) que obtenemos, nuestra distribución de probabilidades se ajustaría a una distribución binomial.
#
# Por lo tanto, la distribución binomial se entiende como una serie de
# pruebas o ensayos en la que solo podemos tener 2 resultados (éxito o
# fracaso), siendo el éxito nuestra variable aleatoria.
#
# ![binomial 2.png](data:image/png;base64,...)

# %% [markdown]
# #Ejercicios planteados
#
# #Caso 1:
#
# variable Aleatoria en Distribución normal
#
# Si X es una variable aleatoria de una distribución ![N.png](data:image/png;base64,...),
#
#
# hallar: ![P1.png](data:image/png;base64,...)

# %% [markdown]
# fórmula para hallar la probabilidad ![Z.png](data:image/png;base64,...)

# %% [markdown]
# Se pide encontrar desviacion standard tipificada Z y se indica que el valor de X esta entre (mu - 3*sigma) y (mu + 3*sigma), donde:
#
# se hace el cambio de variable reemplazamos X por Z quedando:
#
# (Este proceso de llevar cualquier distribución normal a una N(0,1) se llama "tipificación de la variable")
#
# = P( ((mu - 3* sigma) - mu) / sigma <= Z <= ((mu + 3* sigma) - mu) / sigma )
#
# operando parentesis
#
# = P( (mu - 3* sigma - mu) / sigma <= Z <= (mu + 3* sigma - mu) / sigma )
#
# simplificando factores
#
# = P ( -3 <= Z <= 3 )

# %%
from scipy.stats import norm
alpha = round(norm.cdf(3),4)
print(f"valor de Z: {alpha}")
# Out:
# valor de Z:0.9987

# %% [markdown]
# así, según la tabla de normalización standard, para un Z=3 corresponde al 0.9987 y sabiendo que:
# * este valor considera todo el intervalo acumulado hasta la tercera desviación típica,
# * que la distribución es simétrica y
# * que todo el area acumulada suma 1
#
# entonces, la "cola" (1-0.9987) del extremo restante para totalizar 1, debe ser rebajada del 0,9987, para descontar el area opuesta al eje de simetría, quedando:
#
# = 0.9987 - (1-0.9987)
#
# = 0.9987 - 0.0013
#
# = 0.9974
#
# = 99.74 % aprox de los valores de X están dentro de la 3ra desviación típica.

# %% [markdown]
# #Caso 2:
#
# Distribución normal, media y desviación típica
# En una distribución normal de media 4 y desviación típica 2, calcular el valor de a para que: ![P2.png](data:image/png;base64,...)

# %% [markdown]
# Empleando la fórmula: ![Z.png](data:image/png;base64,...)

# %% [markdown]
# Dado que:
#
# mu = 4
#
# sigma = 2
#
# Reemplazamos X por `4 - a` y `4 + a` quedando:
#
# P( ((4 -a ) - 4 )/2 <= z <= ((4 + a) - 4 )/2 ) = 0.5934
#
# Operando paréntesis:
#
# = P( (4 -a - 4 )/2 <= z <= (4 - a + 4 )/2 ) = 0.5934
#
# simplificando:
#
# = P(-a/2 <= z <= a/2) = 0.5934
#
# equivale a 2 veces lado positivo (desde eje 0):
#
# = 2*P(0<=z<=a/2) = 0.5934
#
# desplazando 1/2 para tipificar a N(0,1):
#
# = 2*(P(z<=a/2)-1/2) = 0.5934
#
# operando:
#
# = P(z<=a/2) = 0.5934/2 + 1/2 = 1.5934/2
#
# = P(z<=a/2) = 0.7967
#
# Por lo tanto, los valores de `a` para que se cumpla la probabilidad son:
#
# * a/2 = 0.83
#
# * a = 1.66
#
#
# # estandarizar a la forma
#
# z = (x - mu) / sigma
#
# resultan:
#
# z_lado_- = (4 - a - 4)/2 = -a/2
#
# z_lado_+ = (4 + a - 4)/2 = a/2

# %% [markdown]
# #Caso 3:
#
# Distribución Normal
# Dada una variable aleatoria continua Z, con distribución normal estándar, es decir, N(0;1), encuentre las siguientes probabilidades, usando la tabla.

# %% [markdown]
# a) P(0 ≤ Z ≤ 1,25) = ( 0.8944 - (1 - 0.8944 )) / 2 = 0.3944
#
# * P = 39.44%
#
# b) P(Z ≥ 1,25) = 1 - 0.8944 = 0.1056
#
# * P = 10.56%
#
# c) P(Z ≤ −1,25) = 1 - 0.8944 = 0.1056 = 0.1056
#
# * P = 10.56%
#
# d) P(0 ≤ Z ≤ 1,33) = ( 0.9082 - (1 - 0.9082 )) / 2 = 0.4082
# * P = 40.82%
#
# e) P(Z ≥ 1,33) = 1 - 0.9082 = 0.0918
# * P = 9.18%
#
# f) P(−1,33 ≤ Z ≤ 0) = ( 0.9082 - (1 - 0.9082 )) / 2 = 0.4082 = 0.4082
# * P = 40.82 %

# %% [markdown]
# Caso 4:
# Distribución Binomial.
#
# Uno de los ítems de una prueba sorpresa consta de 12 preguntas de verdadero o falso.
# Suponiendo que los estudiantes no saben contestar a ninguna de ellas y, contestan al azar, hallar la probabilidad de obtener seis aciertos.

# %% [markdown]
# ![binomial.png](data:image/png;base64,...)

# %%
from scipy.special import binom

n=12
p=0.5
k=6
# cálculo coef. binomial n!/k!*(n-k)!
cb=binom(n,k)
prob = cb * (p ** k) * ((1-p) ** (n-k))
print(f"La probabilidad de obtener 6 aciertos es de {prob*100:.2f}%")
# Out:
# La probabilidad de obtener 6 aciertos es de 22.56%

# %% [markdown]
# Definidas:
#
# p= 0.5 (verdadero o falso)
#
# n = 12 preguntas
#
# k = 6 aciertos
#
# coef binomial = 12!/6!*(12-6)! = 924
#
#
# Reemplazando los valores en la fórmula:
#
#
# P = (924) * (0.5 ^ 6) * ( (1-0.5) ^ (12-6))
#
# P = (924) * (0.015625) * ( 0.5 ^ 6 )
#
# P = (924) * (0.015625) * (0.015625)
#
# P = 0.2255
#
# el 22.55 % de probabilidad de obtener 6 aciertos.
